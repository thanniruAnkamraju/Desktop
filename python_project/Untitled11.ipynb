# %%
a=int(input("enter value of a:"))
b=int(input("enter value of b:"))
try:
    c=a*b
    print(c)
except:
    print("exception raised")
else:
    print("no exception raised")
finally:
    print("program ends")
# Out:
# enter value of a:797
# enter value of b:0
# 0
# no exception raised
# program ends

# %%
class A:
    def show(self):
        print("welcome")
    def show(self,firstname=''):
        print("welcome","gowtham")
    def show(self,fistname='',lastname=''):
         print("welcome","goutham","nandha")
obj=A()
obj.show()
# Out:
# welcome goutham nandha

# %%
class A:
    def show(self):
        print("this is a parent class")
class B(A):
    def show(self):
        super().show()
        print("this is a child class")
obj=B()
obj.show()
# Out:
# this is a parent class
# this is a child class

# %%
class parent:
    def func1(self):
        print("this is a function1")
class child:
    def func2(self):
        print("this is a function2")
obj=child()
obj.func2()
# Out:
# this is a function2

# %%
class parent:
    def func1(self):
        print("this is raju")
class parent2:
    def func3(self):
        print("this is aditya")
class child(parent,parent2):
    def func2(self):
        print("raju ajay shasi")
ob=child()
ob.func1()
ob.func2()
# Out:
# this is raju
# raju ajay shasi

# %%
class parent:
    def fuc1(self):
        print("this function 1")
class parent2(parent):
    def func3(self):
        print("this function 2")
class child(parent):
    def func2(self):
        print("this function 3")
obj=child()
ob1=parent2()
ob.func1()
# Out:
# this is raju

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# ...

# %%
# !pip install "C:\Users\ThanniruAnkamraju\Downloads\dlib-19.22.99-cp39-cp39-win_amd64.whl"
# Out:
# Processing c:\users\thanniruankamraju\downloads\dlib-19.22.99-cp39-cp39-win_amd64.whl
# ...

# %%
# !pip install face-recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...

# %%
# %%cmd
# python --version
# Out:
# Microsoft Windows [Version 10.0.19042.1766]
# (c) Microsoft Corporation. All rights reserved.
#
# (base) C:\Users\ThanniruAnkamraju>python --version
# Python 3.9.13
#
# (base) C:\Users\ThanniruAnkamraju>

# %%
# !python --version
# Out:
# Python 3.9.13
